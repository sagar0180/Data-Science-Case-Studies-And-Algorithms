# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import string # special operations on strings

from matplotlib.pyplot import imread
from matplotlib import pyplot as plt

# %matplotlib inline

# %%
conda install -c conda-forge tweepy
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import tweepy

# %%
# Authenticate
#Twitter API credentials
consumer_key = "D2CU1ganhMNlIsGg5uSA0vqyg"
consumer_secret = "qtOhQ63NTkHcojQYbj43OPR9FltpBzfXs5fVNlIzYhR3t4tkxF"
access_key = "1164538827777593344-ImvywLNVup4opxe4lGeczxUX6R64Sb"
access_secret = "w1DvHtq2kYVuY2swbJn3f3GtnkPATCm1BsQzLzzoLJdPq"

# %%
auth = tweepy.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_key, access_secret)
api = tweepy.API(auth)

# %%
# Retrieve Tweets
public_tweets = api.search('Trump')

# %%
for tweet in public_tweets:
    print(tweet.text)
# Out:
# RT @18hariprakash18: Trump said it himself By 2024 or even 2022, US will be gone.We must reverse this now Pay attention to the audits and t…
# trump: which
# RT @CNN: "Even if you don't like the news media, take notice: Secret Justice Department proceedings against the free press affect everyone…
# RT @CNN: "Even if you don't like the news media, take notice: Secret Justice Department proceedings against the free press affect everyone…
# RT @MayoralRafa: Gracias @Serigne_Mbaye_  por defender la dignidad democrática de España frente al racismo de los seguidores de Trump ✊🏼
# The Trump campaign hasn’t yet paid a dime. It owes the El Paso police department more than $381,000 alone. Michael… https://t.co/DYvA9uH0lR
# @TwitterSupport unsuspend @noamchomskyT
#
# You allowed Trump unfettered space to spout dangerous racist, sexist and f… https://t.co/VVwSt9yoRF
# ...

# %%
#print the last five tweets from the account
print("show the five recent tweets: \n")
i=1
for tweet in public_tweets[0:5]:
 print(str(i)+ ') '+ tweet.text + '/n')
 i = i + 1
# Out:
# show the five recent tweets:
#
# 1) RT @18hariprakash18: Trump said it himself By 2024 or even 2022, US will be gone.We must reverse this now Pay attention to the audits and t…/n
# 2) trump: which/n
# 3) RT @CNN: "Even if you don't like the news media, take notice: Secret Justice Department proceedings against the free press affect everyone…/n
# 4) RT @CNN: "Even if you don't like the news media, take notice: Secret Justice Department proceedings against the free press affect everyone…/n
# 5) RT @MayoralRafa: Gracias @Serigne_Mbaye_  por defender la dignidad democrática de España frente al racismo de los seguidores de Trump ✊🏼/n

# %%
#creat a dataframe
import pandas as pd
df= pd.DataFrame([tweet.text for tweet in public_tweets], columns=['Tweets'])

# %%
df
# Out:
#                                                Tweets
# 0   RT @18hariprakash18: Trump said it himself By ...
# 1                                        trump: which
# 2   RT @CNN: "Even if you don't like the news medi...
# 3   RT @CNN: "Even if you don't like the news medi...
# 4   RT @MayoralRafa: Gracias @Serigne_Mbaye_  por ...
# 5   The Trump campaign hasn’t yet paid a dime. It ...
# 6   @TwitterSupport unsuspend @noamchomskyT\n\nYou...
# 7   RT @Zeddary: Clarification: The chinstrap dude...
# 8   RT @kk131066: 2\n\nStop hearing &amp; start li...
# 9   RT @TimHannan: Any religion that had no proble...
# 10  Ivanka Trump, fabulosa en su sexto mes de vaca...
# 11  @njbtweet @TheRickyDavila @mel_giancarlo Every...
# 12  RT @DanScavino: “Now, California is putting Tr...
# 13  If it says I retweeted about trump’s birthday,...
# 14  RT @ChristianWalk1r: I’m a First Time Voter ca...

# %%
df = [Tweets.strip() for Tweets in df.Tweets] # remove both the leading and the trailing characters
df = [Tweets for Tweets in df if Tweets] # removes empty strings, because they are considered in Python as False
df[0:10]
# trailing character = some times we unnecesserily press space after completing statment
# leading character = some times we unnecesserily press space before starting statment

# here we got cleaned data
# Out:
# ['RT @18hariprakash18: Trump said it himself By 2024 or even 2022, US will be gone.We must reverse this now Pay attention to the audits and t…',
#  'trump: which',
#  'RT @CNN: "Even if you don\'t like the news media, take notice: Secret Justice Department proceedings against the free press affect everyone…',
#  'RT @CNN: "Even if you don\'t like the news media, take notice: Secret Justice Department proceedings against the free press affect everyone…',
#  'RT @MayoralRafa: Gracias @Serigne_Mbaye_  por defender la dignidad democrática de España frente al racismo de los seguidores de Trump ✊🏼',
#  'The Trump campaign hasn’t yet paid a dime. It owes the El Paso police department more than $381,000 alone. Michael… https://t.co/DYvA9uH0lR',
#  '@TwitterSupport unsuspend @noamchomskyT\n\nYou allowed Trump unfettered space to spout dangerous racist, sexist and f… https://t.co/VVwSt9yoRF',
# ...

# %%
# Joining the list into one string/text
text = ' '.join(df)
text
# above cell output having multiple seperate statments= to get in one '' statment
# Out:
# 'RT @18hariprakash18: Trump said it himself By 2024 or even 2022, US will be gone.We must reverse this now Pay attention to the audits and t… trump: which RT @CNN: "Even if you don\'t like the news media, take notice: Secret Justice Department proceedings against the free press affect everyone… RT @CNN: "Even if you don\'t like the news media, take notice: Secret Justice Department proceedings against the free press affect everyone… RT @MayoralRafa: Gracias @Serigne_Mbaye_  por defender la dignidad democrática de España frente al racismo de los seguidores de Trump ✊🏼 The Trump campaign hasn’t yet paid a dime. It owes the El Paso police department more than $381,000 alone. Michael… https://t.co/DYvA9uH0lR @TwitterSupport unsuspend @noamchomskyT\n\nYou allowed Trump unfettered space to spout dangerous racist, sexist and f… https://t.co/VVwSt9yoRF RT @Zeddary: Clarification: The chinstrap dude in the picture is not the mob boss in question but Tokhtakhounov DID attend Trump\'s 2013 Mis…
# ...

# %%
len(text)
# Out:
# 1950

# %%
#Punctuation
no_punc_text = text.translate(str.maketrans('', '', string.punctuation)) #with arguments (x, y, z) where 'x' and 'y'
# must be equal-length strings and characters in 'x'
# are replaced by characters in 'y'. 'z'
# is a string (string.punctuation here)
no_punc_text

# here we removing punctuations(;:.,) and connecting with simply space
# Out:
# 'RT 18hariprakash18 Trump said it himself By 2024 or even 2022 US will be goneWe must reverse this now Pay attention to the audits and t… trump which RT CNN Even if you dont like the news media take notice Secret Justice Department proceedings against the free press affect everyone… RT CNN Even if you dont like the news media take notice Secret Justice Department proceedings against the free press affect everyone… RT MayoralRafa Gracias SerigneMbaye  por defender la dignidad democrática de España frente al racismo de los seguidores de Trump ✊🏼 The Trump campaign hasn’t yet paid a dime It owes the El Paso police department more than 381000 alone Michael… httpstcoDYvA9uH0lR TwitterSupport unsuspend noamchomskyT\n\nYou allowed Trump unfettered space to spout dangerous racist sexist and f… httpstcoVVwSt9yoRF RT Zeddary Clarification The chinstrap dude in the picture is not the mob boss in question but Tokhtakhounov DID attend Trumps 2013 Mis… RT kk131066 2\n\nStop hearing amp start liste
# ...

# %%
#Tokenization
from nltk.tokenize import word_tokenize
text_tokens = word_tokenize(no_punc_text)
print(text_tokens[0:50])
# here we transform whole statment into small small chunks
# Out:
# ['RT', '18hariprakash18', 'Trump', 'said', 'it', 'himself', 'By', '2024', 'or', 'even', '2022', 'US', 'will', 'be', 'goneWe', 'must', 'reverse', 'this', 'now', 'Pay', 'attention', 'to', 'the', 'audits', 'and', 't…', 'trump', 'which', 'RT', 'CNN', 'Even', 'if', 'you', 'dont', 'like', 'the', 'news', 'media', 'take', 'notice', 'Secret', 'Justice', 'Department', 'proceedings', 'against', 'the', 'free', 'press', 'affect', 'everyone…']

# %%
len(text_tokens)
# Out:
# 310

# %%
##Removing the stopwords
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
no_stop_tokens = [word for word in text_tokens if not word in stop_words]# here we comparing data from "tokenize-stopword" directory if data is present the stopword already it will not take again
print(no_stop_tokens[0:40])
# Out:
# ['RT', '18hariprakash18', 'Trump', 'said', 'By', '2024', 'even', '2022', 'US', 'goneWe', 'must', 'reverse', 'Pay', 'attention', 'audits', 't…', 'trump', 'RT', 'CNN', 'Even', 'dont', 'like', 'news', 'media', 'take', 'notice', 'Secret', 'Justice', 'Department', 'proceedings', 'free', 'press', 'affect', 'everyone…', 'RT', 'CNN', 'Even', 'dont', 'like', 'news']

# %%
len(no_stop_tokens)
# Out:
# 226

# %%
#Noramalize the data
lower_words = [x.lower() for x in no_stop_tokens]
print(lower_words[0:25])
#uppercase tl lowercase ,Its=its
# Out:
# ['rt', '18hariprakash18', 'trump', 'said', 'by', '2024', 'even', '2022', 'us', 'gonewe', 'must', 'reverse', 'pay', 'attention', 'audits', 't…', 'trump', 'rt', 'cnn', 'even', 'dont', 'like', 'news', 'media', 'take']

# %%
##Joining all the words into single paragraph
df_string = ' '.join(lower_words)

# %%
df_string
# Out:
# 'rt 18hariprakash18 trump said by 2024 even 2022 us gonewe must reverse pay attention audits t… trump rt cnn even dont like news media take notice secret justice department proceedings free press affect everyone… rt cnn even dont like news media take notice secret justice department proceedings free press affect everyone… rt mayoralrafa gracias serignembaye por defender la dignidad democrática de españa frente al racismo de los seguidores de trump ✊🏼 the trump campaign ’ yet paid dime it owes el paso police department 381000 alone michael… httpstcodyva9uh0lr twittersupport unsuspend noamchomskyt you allowed trump unfettered space spout dangerous racist sexist f… httpstcovvwst9yorf rt zeddary clarification the chinstrap dude picture mob boss question tokhtakhounov did attend trumps 2013 mis… rt kk131066 2 stop hearing amp start listening sometimes right words mean wrong things truth set free nojusticenopea… rt timhannan any religion problem donald trump four years sudden found moral b
# ...

# %%
# Import packages
import matplotlib.pyplot as plt
# %matplotlib inline
from wordcloud import WordCloud, STOPWORDS
# Define a function to plot word cloud
def plot_cloud(wordcloud):
    # Set figure size
    plt.figure(figsize=(40, 30))
    # Display image
    plt.imshow(wordcloud) 
    # No axis details
    plt.axis("off");

# %%
# Generate wordcloud
stopwords = STOPWORDS
stopwords.add('will')
wordcloud = WordCloud(width = 3000, height = 2000, background_color='black', max_words=100,colormap='Set2',stopwords=stopwords).generate(text)
# Plot
plot_cloud(wordcloud)

# %%
#Importing postive words
with open ("D:/DATA SCIENCE/1. Data Scientist/Assignment/10. text mining/positive-words.txt","r")as pos:
    poswords = pos.read().split("\n")
    poswords =poswords[10:]
pos_words = ' '.join([word for word in no_stop_tokens if not word in poswords])
cloud_pos = WordCloud(background_color = 'black',width =1800,height =1400).generate(pos_words)
plt.imshow(cloud_pos)

# %%
#Importing negative words
with open ("D:/DATA SCIENCE/1. Data Scientist/Assignment/10. text mining/negative-words.txt","r")as nos:
    negwords = nos.read().split("\n")
    negwords =negwords[10:]
neg_words = ' '.join([word for word in no_stop_tokens if not word in poswords])
cloud_neg = WordCloud(background_color = 'black',width =1800,height =1400).generate(neg_words)
plt.imshow(cloud_neg)

# %%
conda install -c conda-forge textblob
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
 # Perform Sentiment Analysis on Tweets
from textblob import TextBlob
analysis = TextBlob(tweet.text)
print(analysis.sentiment)
print("")
# Out:
# Sentiment(polarity=0.0, subjectivity=0.0)

# %%
# sentiment score is dependent on how clean data is
# polarity tells you how positive/negative is the statment
# subjectivity expresses about personal feelings,views,beliefs
